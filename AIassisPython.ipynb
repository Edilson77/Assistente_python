# %% [markdown]
# <a href="https://colab.research.google.com/github/Edilson77/Assistente_python/blob/main/AIassisPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata
api_key = userdata.get('SECRET_KEY')
import numpy as np
import pandas as pd
import textwrap
from IPython.display import display, Markdown

GOOGLE_API_KEY = api_key
genai.configure(api_key=GOOGLE_API_KEY)

for mdl in genai.list_models():
    if 'embedContent' in mdl.supported_generation_methods:
        print(mdl.name)

# Exemplos de Embed
title = "Regulamento Interno da Universidade EDS7"
sample_text = ("Capítulo 1: Disposições Gerais Artigo 1: Objetivo O presente regulamento tem por objetivo estabelecer normas e diretrizes para o funcionamento interno da Universidade EDS7, visando garantir a ordem, a disciplina e o bem-estar da comunidade acadêmica. "
               "\n"
               "Artigo 2: Âmbito de Aplicação Este regulamento aplica-se a todos os membros da comunidade acadêmica da Universidade EDS7, incluindo estudantes, docentes, funcionários técnico-administrativos e visitantes."
               "\n"
               " Capítulo 2: Direitos e Deveres dos Membros da Comunidade Acadêmica Seção 1: Direitos "
               "\n"
               "Artigo 3: Liberdade de Expressão e Pensamento Todos os membros da comunidade acadêmica têm direito à liberdade de expressão e pensamento, dentro dos limites da lei e da ética."
               "\n"
               " Artigo 4: Acesso à Educação Todos os estudantes têm direito ao acesso à educação e aos recursos educacionais oferecidos pela universidade."
               "\n"
               " Artigo 5: Participação na Vida Universitária Todos os membros da comunidade acadêmica têm direito de participar da vida universitária, incluindo o envolvimento em atividades acadêmicas, culturais e esportivas. Seção 2: Deveres"
               "\n"
               " Artigo 6: Respeito Mútuo Todos os membros da comunidade acadêmica devem tratar uns aos outros com respeito e dignidade. "
               "\n"
               "Artigo 7: Conduta Ética Todos os membros da comunidade acadêmica devem observar os princípios éticos na conduta de suas atividades acadêmicas e profissionais."
               "\n"
               " Artigo 8: Preservação do Patrimônio Todos os membros da comunidade acadêmica são responsáveis pela preservação do patrimônio da universidade, incluindo seus bens materiais e intelectuais. "
               "\n"
               "Capítulo 3: Normas Acadêmicas "
               "\n"
               "Artigo 9: Frequência e Avaliação Os estudantes são obrigados a frequentar as aulas e participar das atividades acadêmicas conforme estabelecido no calendário acadêmico e nos planos de ensino. A avaliação do desempenho acadêmico será realizada por meio de provas, trabalhos e outras atividades avaliativas"
               "\n"
               " Artigo 10: Integridade Acadêmica Todos os membros da comunidade acadêmica devem manter a integridade acadêmica, evitando plágio, cola e outras formas de desonestidade acadêmica. "
               "\n"
               "Artigo 11: Propriedade Intelectual A propriedade intelectual gerada no âmbito das atividades acadêmicas da universidade pertence à instituição, salvo disposição em contrário. "
               "\n"
               "Capítulo 4: Normas Administrativas "
               "\n"
               "Artigo 12: Horário de Funcionamento As dependências da universidade funcionarão de acordo com o horário estabelecido pela administração. "
               "\n"
               "Artigo 13: Uso das Instalações As instalações da universidade devem ser utilizadas de forma adequada e responsável, respeitando as normas de segurança e higiene."
               "\n"
               " Artigo 14: Segurança Todos os membros da comunidade acadêmica são responsáveis por zelar pela segurança do campus e das pessoas que nele circulam. "
               "\n"
               "Capítulo 5: Disposições Finais "
               "\n"
               "Artigo 15: Alterações Este regulamento poderá ser alterado pela administração da universidade, mediante consulta à comunidade acadêmica. "
               "\n"
               "Artigo 16: Vigência Este regulamento entra em vigor na data de sua publicação. "

              )

embeddings = genai.embed_content(model="models/embedding-001",
                              content=sample_text,
                              title=title,
                              task_type="RETRIEVAL_DOCUMENT")
print(embeddings)

DOCUMENT_1 = {
    "Título": "Regulamento Interno da Universidade EDS7",
    "Conteúdo": "Capítulo 1: Disposições Gerais Artigo 1: Objetivo O presente regulamento tem por objetivo estabelecer normas e diretrizes para o funcionamento interno da Universidade EDS7, visando garantir a ordem, a disciplina e o bem-estar da comunidade acadêmica. Artigo 2: Âmbito de Aplicação Este regulamento aplica-se a todos os membros da comunidade acadêmica da Universidade EDS7, incluindo estudantes, docentes, funcionários técnico-administrativos e visitantes. Capítulo 2: Direitos e Deveres dos Membros da Comunidade Acadêmica Seção 1: Direitos Artigo 3: Liberdade de Expressão e Pensamento Todos os membros da comunidade acadêmica têm direito à liberdade de expressão e pensamento, dentro dos limites da lei e da ética. Artigo 4: Acesso à Educação Todos os estudantes têm direito ao acesso à educação e aos recursos educacionais oferecidos pela universidade. Artigo 5: Participação na Vida Universitária Todos os membros da comunidade acadêmica têm direito de participar da vida universitária, incluindo o envolvimento em atividades acadêmicas, culturais e esportivas. Seção 2: Deveres Artigo 6: Respeito Mútuo Todos os membros da comunidade acadêmica devem tratar uns aos outros com respeito e dignidade. Artigo 7: Conduta Ética Todos os membros da comunidade acadêmica devem observar os princípios éticos na conduta de suas atividades acadêmicas e profissionais. Artigo 8: Preservação do Patrimônio Todos os membros da comunidade acadêmica são responsáveis pela preservação do patrimônio da universidade, incluindo seus bens materiais e intelectuais. Capítulo 3: Normas Acadêmicas Artigo 9: Frequência e Avaliação Os estudantes são obrigados a frequentar as aulas e participar das atividades acadêmicas conforme estabelecido no calendário acadêmico e nos planos de ensino. A avaliação do desempenho acadêmico será realizada por meio de provas, trabalhos e outras atividades avaliativas Artigo 10: Integridade Acadêmica Todos os membros da comunidade acadêmica devem manter a integridade acadêmica, evitando plágio, cola e outras formas de desonestidade acadêmica. Artigo 11: Propriedade Intelectual A propriedade intelectual gerada no âmbito das atividades acadêmicas da universidade pertence à instituição, salvo disposição em contrário. Capítulo 4: Normas Administrativas Artigo 12: Horário de Funcionamento As dependências da universidade funcionarão de acordo com o horário estabelecido pela administração. Artigo 13: Uso das Instalações As instalações da universidade devem ser utilizadas de forma adequada e responsável, respeitando as normas de segurança e higiene. Artigo 14: Segurança Todos os membros da comunidade acadêmica são responsáveis por zelar pela segurança do campus e das pessoas que nele circulam. Capítulo 5: Disposições Finais Artigo 15: Alterações Este regulamento poderá ser alterado pela administração da universidade, mediante consulta à comunidade acadêmica. Artigo 16: Vigência Este regulamento entra em vigor na data de sua publicação. "}
DOCUMENT_2 = {
    "Título": "Biblioteca da Universidade EDS7",
    "Conteúdo": "Ciência da Computação: Código Limpo: Habilidades Práticas do Agile Software - Robert C. Martin (ISBN 9788576082673) Introdução à Computação - Tucker & Noonan (ISBN 9788521617423) Algoritmos: Teoria e Prática - Cormen, Leiserson, Rivest & Stein (ISBN 9788535236997) Padrões de Arquitetura de Aplicações Corporativas - Martin Fowler (ISBN 9788575227258) Domain-Driven Design: Atacando as Complexidades no Coração do Software - Eric Evans (ISBN 9788576087937) Código Completo 2 - Steve McConnell (ISBN 9788573937768) Use a Cabeça!: Padrões de Projetos - Freeman, Bates, Sierra & Robson (ISBN 9788576081270) Programando em Python - Mark Lutz (ISBN 9788575228163) C++: Como Programar - Deitel & Deitel (ISBN 9788535246408) Java: Como Programar - Deitel & Deitel (ISBN 9788535266826) Engenharia de Software: Engenharia de Software: Uma Abordagem Profissional - Roger S. Pressman (ISBN 9788521619786) O Mítico Homem-Mês: Ensaios sobre Engenharia de Software - Frederick Brooks Jr. (ISBN 9788575222796) Engenharia de Requisitos: Software Orientado ao Negócio - Karl Wiegers & Joy Beatty (ISBN 9788575222420) Test-Driven Development: By Example - Kent Beck (ISBN 9780321146533) Refatoração: Aperfeiçoando o Design de Código Existente - Martin Fowler (ISBN 9788575227258) Inteligência Artificial: Inteligência Artificial: Uma Abordagem Moderna - Russel & Norvig (ISBN 9788521617423) Deep Learning - Goodfellow, Bengio & Courville (ISBN 9780262035613) Artificial Intelligence: A Guide for Thinking Humans - Melanie Mitchell (ISBN 9780374257837) Superintelligence: Paths, Dangers, Strategies - Nick Bostrom (ISBN 9780198739838) Cibersegurança: A Arte da Enganação: Controlando o Fator Humano na Segurança da Informação - Kevin Mitnick & William Simon (ISBN 9788575221782) Hacking: A Arte da Exploração - Jon Erickson (ISBN 9788575221386) Cibersegurança: Ameaças, Tecnologias e Práticas - Nina Godbole & Sunit Belapure (ISBN 9788575226558) Engenharia Civil: Resistência dos Materiais - Hibbeler (ISBN 9788587918612) Mecânica dos Sólidos - Beer, Johnston & DeWolf (ISBN 9788521616341) Fundamentos da Análise Estrutural - Leet, Uang & Gilbert (ISBN 9788521615641) Engenharia Mecânica: Fundamentos da Termodinâmica - Borgnakke & Sonntag (ISBN 9788521617638) Mecânica dos Fluidos - Frank M. White (ISBN 9788521616112) Transferência de Calor e Massa: Uma Abordagem Prática - Yunus A. Cengel (ISBN 9788521617317) Engenharia Elétrica: Circuitos Elétricos - Nilsson & Riedel (ISBN 9788521619625) Eletrônica: Dispositivos e Circuitos - Boylestad & Nashelsky (ISBN 9788521617621) Máquinas Elétricas e Sistemas de Potência - Wildi (ISBN 9788521616075) Engenharia Química: Princípios de Processos Químicos - Felder & Rousseau (ISBN 9788521617768) Fenômenos de Transporte - Bird, Stewart & Lightfoot (ISBN 9780470115398) Operações Unitárias da Engenharia Química - McCabe, Smith & Harriott (ISBN 9780070448256) Big Data e Data Science: Big Data: Como Extrair Volume, Variedade, Velocidade e Valor de Big Data - Mayer-Schönberger & Cukier (ISBN 9788575225346) Data Science para Negócios: O que Você Precisa Saber sobre Mineração de Dados e Pensamento Analítico de Dados - Provost & Fawcett (ISBN 9788575225629) Python para Data Analysis - McKinney (ISBN 9781449319793) Computação em Nuvem: Computação em Nuvem: Princípios, Sistemas e Aplicações - Buyya, Vecchiola & Selvi (ISBN 9780128014431) AWS Certified Solutions Architect Official Study Guide: Associate Exam - Joe Baron, Ben Piper & Tim Bixler (ISBN 9781119137791) Desenvolvimento Web: Use a Cabeça!: HTML com CSS e XHTML - Sierra & Bates (ISBN 9788576080907) Use a Cabeça!: Javascript - Sierra & Bates (ISBN 9788576080914) Use a Cabeça!: PHP & MySQL - Steyer & Welling (ISBN 9788576080921)Engenharia Biomédica: Introdução à Engenharia Biomédica - John Enderle & Joseph Bronzino (ISBN 9780123749796) Biomateriais: Uma Introdução - Joon Park & Buddy Ratner (ISBN 9780306451134) Engenharia Aeroespacial: Introdução ao Voo - John D. Anderson Jr. (ISBN 9780073398273) Fundamentos da Aerodinâmica - John D. Anderson Jr. (ISBN 9780073398167) Engenharia Ambiental:Engenharia Ambiental: Conceitos, Tecnologia e Gestão - Davis & Masten (ISBN 9780073398273) Química Ambiental - Colin Baird & Michael Cann (ISBN 9781429201476) Nanotecnologia: Nanotecnologia: Introdução à Nanotecnologia - Charles P. Poole Jr. & Frank J. Owens (ISBN 9780471079354) Nanomateriais - A.K. Bandyopadhyay (ISBN 9780070649483)"}
DOCUMENT_3 = {
    "Título": "Portifolio da Universidade EDS7",
    "Conteúdo": "Apresentação: A EDS7, fundada em 2004, se destaca como uma instituição de ensino superior de excelência, comprometida com a formação integral de cidadãos e profissionais éticos e inovadores. Com um legado de 20 anos dedicados à produção e disseminação do conhecimento, a EDS7 se tornou referência em Tecnologia e atua como agente transformador da sociedade. Missão e Valores: Nossa missão é promover a excelência no ensino, pesquisa e extensão, visando o desenvolvimento social e econômico do país. Pautamos nossas ações nos valores da ética, do humanismo, da sustentabilidade e da busca constante pela inovação. Diferenciais: Corpo Docente: Contamos com um corpo docente altamente qualificado, composto por professores com experiência acadêmica e profissional, atuando em projetos de pesquisa e extensão de relevância nacional e internacional. Infraestrutura Moderna: Oferecemos aos nossos alunos uma infraestrutura moderna e completa, com laboratórios equipados, bibliotecas com amplo acervo, salas de aula interativas e espaços de convivência que estimulam a troca de conhecimentos. Formação Inovadora: Nossos cursos de graduação e pós-graduação são elaborados com base em metodologias ativas de ensino-aprendizagem, estimulando o desenvolvimento de habilidades essenciais para o mercado de trabalho, como criatividade, pensamento crítico, comunicação e trabalho em equipe. Internacionalização: Buscamos ampliar as oportunidades de intercâmbio acadêmico e cultural, oferecendo programas de dupla diplomação, convênios com universidades estrangeiras e a possibilidade de participação em projetos internacionais. Responsabilidade Social: Acreditamos no papel da universidade na construção de uma sociedade mais justa e sustentável. Por meio de projetos de extensão, levamos conhecimento e serviços à comunidade, contribuindo para a solução de problemas sociais. Destaques: Pesquisa: A EDS7 é reconhecida pela qualidade de sua produção científica, com destaque para [Mencionar áreas de pesquisa de destaque]. Extensão: Desenvolvemos projetos de extensão em diversas áreas, como [Citar áreas de atuação], impactando positivamente a vida de milhares de pessoas. Inovação: Incubamos empresas e startups, apoiando o desenvolvimento de ideias inovadoras e a geração de novos negócios. Prêmios e Reconhecimentos: A excelência da EDS7 é comprovada por [Citar prêmios e reconhecimentos recebidos]. Futuro: A EDS7 está em constante evolução, buscando sempre aprimorar seus cursos, investir em pesquisa e inovação e ampliar sua atuação na comunidade. Nosso compromisso é continuar formando cidadãos engajados, profissionais competentes e líderes capazes de transformar o futuro. Anexos: Catálogo de cursos de Graduação e Pós-Graduação Relatório Anual de Atividades Mapa de localização dos Campi Vídeo Institucional Informações de Nome: Edilson Da Sara Contato:Website: edilsondasara.netlify.app E-mail: edilsondasara07@gmail.com Telefone: +258845236338"}
documents = [DOCUMENT_1, DOCUMENT_2, DOCUMENT_3]
df = pd.DataFrame(documents)
df.columns = ["Título", "Conteúdo"]

model = "models/embedding-001"


def embed_fn(title, text):
    return genai.embed_content(model="models/embedding-001",
                              content=text,
                              title=title,
                              task_type="RETRIEVAL_DOCUMENT")["embedding"]


df["Embeddings"] = df.apply(lambda row: embed_fn(row["Título"], row["Conteúdo"]), axis=1)
# print(df)

def gerar_buscar_consulta(consulta, base, model):
    embedding_da_consulta = genai.embed_content(model=model,
                                                content=consulta,
                                                task_type="RETRIEVAL_QUERY")
    produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta["embedding"])
    indice = np.argmax(produtos_escalares)
    return df.iloc[indice]["Conteúdo"]

generation_config = {
    "candidate_count": 1,
    "temperature": 0.2,
}

model_2 = genai.GenerativeModel("gemini-1.0-pro",
                              generation_config=generation_config)
chat = model_2.start_chat(history=[])

# Função auxiliar para formatar texto como Markdown
def to_markdown(text):
    text = text.replace('•', '  *')
    return Markdown(textwrap.indent(text, '> ', lambda line: True))

while True:
    consulta = input("Digite alguma coisa:")

    if consulta == "fim":
        break

    resposta = gerar_buscar_consulta(consulta, df, model)
    print(resposta)

    prompt = f"Com base na minha pesquisa, preciso apenas da seguinte informação da sua resposta: {consulta}. Por favor, reformule a resposta de forma direta e formal, eliminando o contexto irrelevante dentro disto: {resposta}"

    # Envia a mensagem para o chat
    response = chat.send_message(prompt)

    # Extrai o conteúdo da resposta do chat
    chat_response = response.parts[0].text

    # Imprime a resposta formatada como Markdown
    for message in chat.history:
        role_text = f"**{message.role}**: {message.parts[0].text}"
        display(to_markdown(role_text).data)
        print('================================****CHAT-BOT-&-GERADOR_DE_CONTEÚDO****================================')
